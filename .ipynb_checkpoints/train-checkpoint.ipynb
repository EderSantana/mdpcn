# %%
# %matplotlib inline
import numpy as np
from pylab import *
import theano
import pylearn2.models.mlp
import cdpcn
import silentmlp
#import vidtimit
from vidtimit import VIDTIMIT
#reload(vidtimit)
from trainer import Trainer
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
import cPickle
dataset = VIDTIMIT('train', axes=('b','c',0,1), center=True)
monitoring_dataset = {'nada': VIDTIMIT('test', axes=('b','c',0,1))}

# %%
from pylearn2.space import Conv2DSpace
from pylearn2.models.mlp import IdentityConvNonlinearity, RectifierConvNonlinearity
chan = 16
bsize = 8
model = silentmlp.SilentMLP(
      batch_size=bsize,
      layers= [
               cdpcn.ConvSparseCoding(
                   fprop_code = True,
                   top_most = False,
                   batch_size = bsize
                   lr = .001,
                   lbda = .1,
                   n_steps = 10,
                   output_channels = chan,
                   kernel_shape= [5, 5],
                   pool_shape= [1, 1],
                   pool_stride= [1, 1],
                   pool_type = 'max',
                   irange = .0001,
                   layer_name = 'h0',
                   nonlinearity = RectifierConvNonlinearity()
               ),
               cdpcn.ConvSparseCoding(
                   fprop_code = True,
                   top_most = True,
                   batch_size = bsize,
                   lr = .001,
                   lbda = .1,
                   n_steps = 10,
                   input_channels = chan,
                   output_channels = chan,
                   kernel_shape= [5, 5],
                   pool_shape= [1, 1],
                   pool_stride= [1, 1],
                   pool_type = 'max',
                   irange = .0001,
                   layer_name = 'h1',
                   nonlinearity = IdentityConvNonlinearity()
               ),
               pylearn2.models.mlp.Softmax (
                   max_col_norm= 1.9365,
                   layer_name= 'y',
                   n_classes= 10,
                   irange= .005
              )
              ],
      input_space=Conv2DSpace(
            shape= [32, 32],
            num_channels= 1,
            axes=('b','c',0,1)
      )
)

# %%
from sparse_costs import ConvSparseReconstructionError, SparseReconstructionError
cost = ConvSparseReconstructionError()
trainer = Trainer(cost, model, dataset, monitoring_dataset, .06, './results.pkl',1)

# %%
# Run this to load a 25x25 filter trained with 100 steps
model = cPickle.load(file('model.pkl'))
trainer = Trainer(cost, model, dataset, monitoring_dataset, .06, './results.pkl',10)

# %%
#trainer.train_epoch()
trainer.main_loop()
# Out:
# ============
# Epoch: 0
# $> Compiling optimizer.
# $> Compiling optimizer.
# $> Compiling optimizer.
# /Users/eder/Copy/python/top/__init__.py:139: UserWarning: The parameter 'updates' of theano.function() expects an OrderedDict, got <type 'dict'>. Using a standard dictionary here results in non-deterministic behavior. You should use an OrderedDict if you are using Python 2.7 (theano.compat.python2x.OrderedDict for older python), or use a list of (shared, update) pairs. Do not just convert your dictionary to this type before the call as the conversion will still be non-deterministic.
#   self.f = theano.function([], self.cost, updates=updates, givens=self.givens, allow_input_downcast=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-176002d6e9e4> in <module>()
#       1 #trainer.train_epoch()
# ----> 2 trainer.main_loop()
#
# /Users/eder/Copy/python/dpcn/trainer.py in main_loop(self)
#      33         for e in xrange(self.epochs):
#      34             print "\n============ \nEpoch: %d" % e
# ---> 35             self.train_epoch()
#      36             if 'valid' in self.monitoring_dataset.keys():
#      37                 self.validate_and_save()
#
# /Users/eder/Copy/python/dpcn/trainer.py in train_epoch(self)
#      52             self._train_err = 0.
#      53             for t in range(data_batch.shape[1]):
# ---> 54                 self.update_hidden_codes(data_batch[:,t:t+1,:,:])
#      55                 _, err = self.opt.run(1)
#      56                 self._train_err += err
#
# /Users/eder/Copy/python/dpcn/trainer.py in update_hidden_codes(self, batch)
#     117                 else:
#     118                     X = Y
# --> 119                 sc = L.get_sparse_code(X)
#     120                 Y  = self.compiled_fprop[l](X)
#     121
#
# /Users/eder/Copy/python/dpcn/cdpcn.py in get_sparse_code(self, state_below)
#     483             s_below = state_below[:,:self.input_channels,:,:].astype('float32')
#     484             self.S.set_value(s_below)
# --> 485             self.opt.run(self.n_steps)#,
#     486             #np.arange(self.batch_size))
#     487         #else:
#
# /Users/eder/Copy/python/top/__init__.py in run(self, niter, *args)
#     152       self.compile()
#     153     for k in range(niter):
# --> 154       total += self.f(*args)
#     155     return self, total
#     156
#
# /Users/eder/ENV/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     577         t0_fn = time.time()
#     578         try:
# --> 579             outputs = self.fn()
#     580         except Exception:
#     581             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:

# %%
# Save actual model
import cPickle
cPickle.dump(model, file('model_small.pkl','w'), -1)

# %%
import display_data
W = model.get_params()[0].get_value(borrow=True)
d = display_data.displayData(W[0].reshape((16,25)),'w.png')
subplot(121)
imshow(d,cmap='gray')

subplot(122)
W = model.layers[1].transformer.get_params()[0].get_value(borrow=True)
d = display_data.displayData(W[0].reshape((16,25)),'w.png')
imshow(d,cmap='gray')
